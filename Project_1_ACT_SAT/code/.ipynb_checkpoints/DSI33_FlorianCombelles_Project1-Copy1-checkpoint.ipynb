# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Decide on your problem statement that will guide your analysis for this project. For guidelines, sample prompts, or inspiration, check out the README.
#
# ###### The ministry of Education has hired you in order to advise on the impacts of Covid and somes states going test optional in regards to the participation and scores.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **To-Do:** *Fill out this cell (or edit the above cell) with any other background or information that is necessary for your problem statement.*

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **To-Do:** *Fill out this cell with the datasets you will use for your analysis. Write a brief description of the contents for each dataset that you choose.*

# %% [markdown]
# Datasets used for this projects:
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2012.csv`](./data/act_2012.csv): 2020 ACT Scores by State
# * [`act_2021.csv`](./data/act_2021.csv): 2021 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2020.csv`](./data/sat_2020.csv): 2020 SAT Scores by State
# * [`sat_2021.csv`](./data/sat_2021.csv): 2021 SAT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# During Covid, universities re-examined the SAT/ACT requirement for applications.
#     - Testing sites were closed or disrupted
#     - Students couldn't prepare for the tests in optimal conditions
#
# Some univeristies decided to become either:
#     - Test Optional
#         . Students can still submit their results with their applications but it is not required
#     - Test blind
#         . ACT and SAT results are not counted for admission of applications (but maybe for grants ?)
#     - Eliminated tests
#         . Tests are not considered for any part of the application
#
# Going test optional increase college accessibility especially for student with lower income family and/or from minorities
#     - Higher SAT scores results come from families with an income superior to 200,000 while lowest scores comes from families with income inferior to 20,000
#     - Hispanic and African American students of similar income usually scores lower than their Asian and White counterparts.
#
# Sources:
# https://newsroom.collegeboard.org/sat-program-results-capture-impact-of-covid-on-class-of-2021
#
# https://act.edu.sg/sat-vs-act/?utm_source=google&utm_medium=cpc&utm_campaign=ACT-generic-tCPA&utm_keyword=sat%20act&matchtype=p&device=c&adposition=&adgroupid=112386874221&gclid=CjwKCAjwzY2bBhB6EiwAPpUpZuIWUK3kD0_LduO0c1oOWhgCDOvw_kP8xho6WODclzC9j1GwA_fuBhoCfeUQAvD_BwE
#
# https://blog.arborbridge.com/test-optional-test-blind-what-difference
#
# https://www.collegedata.com/resources/prepare-and-apply/test-optional-test-blind-whats-the-difference
#
# https://www.forbes.com/sites/markkantrowitz/2021/05/21/how-admissions-tests-discriminate-against-low-income-and-minority-student-admissions-at-selective-colleges/?sh=16ae073f3cc1

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Create a function called mean_calc to calculate the mean of a list of values.
# Initiate a counter that will be used to get the sum of the values in the list
# Create a loop that will go through all the values in value list
# Increment the total_value counter will all the values from the value list
# Divide the total value by the amount of items in the value list

def mean_calc(value_list):
    total_value = 0
    for value in value_list:
        total_value += value
        mean_value = total_value / len(value_list)
    return mean_value

# %%
# Alternate version 
def mean_calc_alt(value_list_alt):
    mean_value_alt = sum(value_list_alt) / len(value_list_alt)
    return mean_value_alt

# %%
print(mean_calc([100,255,864,254,639,548,369,512,354,147,556,752,364,152]))
print(mean_calc_alt([100,255,864,254,639,548,369,512,354,147,556,752,364,152]))
# Out:
# 419.0
# 419.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Creating a function that calculates the standard deviation

def dev_calc(value_list):
    sum_sqr =[]
    avg_num = mean_calc_alt(value_list)
    for number in value_list:
        #ind_dev = number - avg_num
        sum_sqr.append((number - avg_num) ** 2)
    sum_ind_dev = sum(sum_sqr)
    var = (sum_ind_dev / len(value_list)) ** 0.5
       # dev = var ** 0.5
    return var

# %%
# Testing my standard deviation function

dev_calc([2,3,5,6,7,8,3,5,6])
# Out:
# 1.8856180831641267

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Creating a function that will convert a percentage number into a decimal number

def perc_conv(num): # Define a function percentage converter
    num_conv = num.strip('%') # Define a variable that will remove the '%' from the number
    num_dec = float(num_conv) / 100 # Define a variable that will convert the number to a float and divide it by 100 to obtain the decimal value
    return num_dec

# %%
# Testing the percentage converter function

perc_conv('30.5%')
# Out:
# 0.305

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Importing necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Loading the datasets

act_2017 = pd.read_csv('../data/act_2017.csv')
act_2018 = pd.read_csv('../data/act_2018.csv')
act_2019 = pd.read_csv('../data/act_2019.csv')
act_2020 = pd.read_csv('../data/act_2020.csv')
act_2021 = pd.read_csv('../data/act_2021.csv')
sat_2017 = pd.read_csv('../data/sat_2017.csv')
sat_2018 = pd.read_csv('../data/sat_2018.csv')
sat_2019 = pd.read_csv('../data/sat_2019.csv')
sat_2020 = pd.read_csv('../data/sat_2020.csv')
sat_2021 = pd.read_csv('../data/sat_2021.csv')

# %%
# Creating a list of imported files

csv_list = [act_2017,act_2018,act_2019,act_2020,act_2021,sat_2017,sat_2018,sat_2019,sat_2020,sat_2021]

# %%
# Creating a function to print the types of all file imported

def csv_type(csv_list):
    for csv in csv_list:
        print(type(csv))

# %%
# Calling the previous function to display the types of the file imported

csv_type(csv_list)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ##### Question 1: Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
# Crerating a function to print out the first 5 rows of each file imported

def disp_data(csv_list):
    for file in csv_list:
        print(file.head(5))

# %%
# Calling out the previous function to print out the first 5 rows of each imported file in csv_list

disp_data(csv_list)
# Out:
#       State Participation  English  Math  Reading  Science  Composite
# 0  National           60%     20.3  20.7     21.4     21.0       21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4       19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9       19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5       19.4
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
#        State  Participation  English  Math  Reading  Science  Composite
# ...

# %% [markdown]
# #### Question 2: Check for missing values.

# %%
# Creating a function that will display the info of all imported files

def miss_val_chk(csv_list):
    for file in csv_list:
        print(file.info())

# %%
# Callout the previous function to display the info of all imported files in file_list
miss_val_chk(csv_list)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(5), object(2)
# memory usage: 3.0+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB
# None
# ...

# %% [markdown]
# #### Question 8: Drop unnecessary columns.

# %%
# Dropping the English,Math,Reading and Science columns from 2017,2020 and 2021 as they are not in 2018 and 2019

act_2017.drop(columns=[
    'English',
    'Math',
    'Reading',
    'Science'], inplace=True)

act_2020.drop(columns=[
    'English',
    'Math',
    'Reading',
    'Science'], inplace=True)

act_2021.drop(columns=[
    'English',
    'Math',
    'Reading',
    'Science'], inplace=True)

# %% [markdown]
# #### Question 7: Rename Columns.
#     . Column names should be all lowercase.
#     . Column names should not contain spaces (underscores will suffice--this allows for using the df.column_name method to access columns in addition

# %%
# Renaming all the columns to make it easier to refer to them
# Create a function that will force the columns names into lower case AND replace the spaces with underscores

def rname_cols(file_list):
    for file in file_list:
        file.columns = (file.columns.str.lower())
        file.columns = (file.columns.str.replace(' ','_'))
        print(file.head())

# %%
rname_cols(csv_list)
# Out:
#       state participation  composite
# 0  National           60%       21.0
# 1   Alabama          100%       19.2
# 2    Alaska           65%       19.8
# 3   Arizona           62%       19.7
# 4  Arkansas          100%       19.4
#         state participation  composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#         state participation  composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6
#        state  participation  composite
# 0   National      45.740349       20.7
# 1   Alabama      100.000000       18.8
# 2    Alaska       33.000000       20.1
# 3   Arizona       71.000000       19.1
# 4  Arkansas      100.000000       19.0
# ...

# %%
# Renaming the participation and composite columns in act files prior to merge

act_2017.rename(columns={
    'participation':'part_2017',
    'composite':'comp_2017'}, inplace=True)

act_2018.rename(columns={
    'participation':'part_2018',
    'composite':'comp_2018'}, inplace=True)

act_2019.rename(columns={
    'participation':'part_2019',
    'composite':'comp_2019'}, inplace=True)

act_2020.rename(columns={
    'participation':'part_2020',
    'composite':'comp_2020'}, inplace=True)

act_2021.rename(columns={
    'participation':'part_2021',
    'composite':'comp_2021'}, inplace=True)

# %%
# Renaming the columns in sat files prior to merge

sat_2017.rename(columns={
    'participation':'part_2017',
    'evidence-based_reading_and_writing':'ebrw_2017',
    'math':'math_2017',
    'total':'total_2017'}, inplace=True)

sat_2018.rename(columns={
    'participation':'part_2018',
    'evidence-based_reading_and_writing':'ebrw_2018',
    'math':'math_2018',
    'total':'total_2018'}, inplace=True)

sat_2019.rename(columns={
    'participation':'part_2019',
    'ebrw':'ebrw_2019',
    'math':'math_2019',
    'total':'total_2019'}, inplace=True)

sat_2020.rename(columns={
    'participation':'part_2020',
    'evidence-based_reading_and_writing':'ebrw_2020',
    'math':'math_2020',
    'total':'total_2020'}, inplace=True)

sat_2021.rename(columns={
    'participation':'part_2021',
    'evidence-based_reading_and_writing':'ebrw_2021',
    'math':'math_2021',
    'total':'total_2021'}, inplace=True)

# %%
# Removing white space in ACT and SAT file for years 2020 and 2021 in the state column.

act_2020["state"] = act_2020["state"].map(lambda x: x.strip())
act_2021["state"] = act_2021["state"].map(lambda x: x.strip())

sat_2020["state"] = sat_2020["state"].map(lambda x: x.strip())
sat_2021["state"] = sat_2021["state"].map(lambda x: x.strip())

# %% [markdown]
# #### Question 3: Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).

# %%
# Checking if there is any ACT score below or above the correct range
 
print(act_2017[(act_2017['comp_2017'] < 1) | (act_2017['comp_2017'] > 36)])
print(act_2018[(act_2018['comp_2018'] < 1) | (act_2018['comp_2018'] > 36)])
print(act_2019[(act_2019['comp_2019'] < 1) | (act_2019['comp_2019'] > 36)])
print(act_2020[(act_2020['comp_2020'] < 1) | (act_2020['comp_2020'] > 36)])
print(act_2021[(act_2021['comp_2021'] < 1) | (act_2021['comp_2021'] > 36)])
# Out:
# Empty DataFrame
# Columns: [state, part_2017, comp_2017]
# Index: []
# Empty DataFrame
# Columns: [state, part_2018, comp_2018]
# Index: []
# Empty DataFrame
# Columns: [state, part_2019, comp_2019]
# Index: []
# Empty DataFrame
# Columns: [state, part_2020, comp_2020]
# Index: []
# Empty DataFrame
# Columns: [state, part_2021, comp_2021]
# Index: []

# %%
# Print null values in the dataframes
act_2018.isnull()
# Out:
#     state  part_2018  comp_2018
# 0   False      False      False
# 1   False      False      False
# 2   False      False      False
# 3   False      False      False
# 4   False      False      False
# 5   False      False      False
# 6   False      False      False
# 7   False      False      False
# 8   False      False      False
# 9   False      False      False
# 10  False      False      False
# 11  False      False      False
# 12  False      False      False
# 13  False      False      False
# 14  False      False      False
# 15  False      False      False
# 16  False      False      False
# 17  False      False      False
# 18  False      False      False
# 19  False      False      False
# 20  False      False      False
# 21  False      False      False
# 22  False      False      False
# 23  False      False      False
# 24  False      False      False
# 25  False      False      False
# 26  False      False      False
# 27  False      False      False
# ...

# %%
# Checking if there is any SAT score below or above the correct range

print(sat_2017[(sat_2017['ebrw_2017'] < 200) | (sat_2017['ebrw_2017'] > 800)])
print(sat_2017[(sat_2017['math_2017'] < 200) | (sat_2017['math_2017'] > 800)])
print(sat_2017[(sat_2017['total_2017'] < 400) | (sat_2017['total_2017'] > 1600)])

print(sat_2018[(sat_2018['ebrw_2018'] < 200) | (sat_2018['ebrw_2018'] > 800)])
print(sat_2018[(sat_2018['math_2018'] < 200) | (sat_2018['math_2018'] > 800)])
print(sat_2018[(sat_2018['total_2018'] < 400) | (sat_2018['total_2018'] > 1600)])

print(sat_2019[(sat_2019['ebrw_2019'] < 200) | (sat_2019['ebrw_2019'] > 800)])
print(sat_2019[(sat_2019['math_2019'] < 200) | (sat_2019['math_2019'] > 800)])
print(sat_2019[(sat_2019['total_2019'] < 400) | (sat_2019['total_2019'] > 1600)])

print(sat_2020[(sat_2020['ebrw_2020'] < 200) | (sat_2020['ebrw_2020'] > 800)])
print(sat_2020[(sat_2020['math_2020'] < 200) | (sat_2020['math_2020'] > 800)])
print(sat_2020[(sat_2020['total_2020'] < 400) | (sat_2020['total_2020'] > 1600)])

print(sat_2021[(sat_2021['ebrw_2021'] < 200) | (sat_2021['ebrw_2021'] > 800)])
print(sat_2021[(sat_2021['math_2021'] < 200) | (sat_2021['math_2021'] > 800)])
print(sat_2021[(sat_2021['total_2021'] < 400) | (sat_2021['total_2021'] > 1600)])
# Out:
# Empty DataFrame
# Columns: [state, part_2017, ebrw_2017, math_2017, total_2017]
# Index: []
#        state part_2017  ebrw_2017  math_2017  total_2017
# 20  Maryland       69%        536         52        1060
# Empty DataFrame
# Columns: [state, part_2017, ebrw_2017, math_2017, total_2017]
# Index: []
# Empty DataFrame
# Columns: [state, part_2018, ebrw_2018, math_2018, total_2018]
# Index: []
# Empty DataFrame
# Columns: [state, part_2018, ebrw_2018, math_2018, total_2018]
# Index: []
# Empty DataFrame
# Columns: [state, part_2018, ebrw_2018, math_2018, total_2018]
# Index: []
# Empty DataFrame
# Columns: [state, part_2019, ebrw_2019, math_2019, total_2019]
# Index: []
# Empty DataFrame
# Columns: [state, part_2019, ebrw_2019, math_2019, total_2019]
# Index: []
# Empty DataFrame
# Columns: [state, part_2019, ebrw_2019, math_2019, total_2019]
# Index: []
# Empty DataFrame
# Columns: [state, part_2020, ebrw_2020, math_2020, total_2020]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# #### Question 4: Fix any errors you identified in steps 2-3.

# %%
sat_2021
# Out:
#                    state  part_2021  ebrw_2021  math_2021  total_2021
# 0               National  41.128074        533        528        1060
# 1                Alabama   3.000000        591        568        1159
# 2                 Alaska  23.000000        567        553        1119
# 3                Arizona  11.000000        592        589        1181
# 4               Arkansas   2.000000        610        584        1194
# 5             California  24.000000        527        530        1057
# 6               Colorado  56.000000        544        528        1072
# 7            Connecticut  69.000000        545        527        1072
# 8               Delaware  96.000000        499        485         984
# 9   District of Columbia  90.000000        500        487         987
# 10               Florida  81.000000        513        480         993
# 11               Georgia  41.000000        551        534        1086
# ...

# %%
# Replacing incorrect value for Maryland math 2017 with the mean of all other years

sat_2017.loc[sat_2017['state'] == 'Maryland','math_2017'] = (1060 - 536)

# Making sure that the value has been correctly replaced
print(sat_2017[sat_2017['state'] == 'Maryland'])
# Out:
#        state part_2017  ebrw_2017  math_2017  total_2017
# 20  Maryland       69%        536        524        1060

# %%
# Dropping Puerto Rico and Virgin Island from sat_2019

sat_2019.drop(index=[39,47], inplace=True)

# %%
# Converting the percentage into decimals

act_2017['part_2017'] = act_2017['part_2017'].map(perc_conv)
act_2018['part_2018'] = act_2018['part_2018'].map(perc_conv)
act_2019['part_2019'] = act_2019['part_2019'].map(perc_conv)

act_2020['part_2020'] = act_2020['part_2020'].map(lambda x: round(x/100, 2))
act_2021['part_2021'] = act_2021['part_2021'].map(lambda x: round(x/100, 2))

sat_2017['part_2017'] = sat_2017['part_2017'].map(perc_conv)
sat_2018['part_2018'] = sat_2018['part_2018'].map(perc_conv)
sat_2019['part_2019'] = sat_2019['part_2019'].map(perc_conv)

sat_2020['part_2020'] = sat_2020['part_2020'].map(lambda x: round(x/100, 2))
sat_2021['part_2021'] = sat_2021['part_2021'].map(lambda x: round(x/100, 2))

# %% [markdown]
# #### Question 5 :Display the data types of each feature.

# %%
# Return the dtypes of the csv files

for file in csv_list:
    print(file.dtypes)
# Out:
# state         object
# part_2017    float64
# comp_2017    float64
# dtype: object
# state         object
# part_2018    float64
# comp_2018    float64
# dtype: object
# state         object
# part_2019    float64
# comp_2019    float64
# dtype: object
# state         object
# part_2020    float64
# comp_2020    float64
# dtype: object
# state         object
# part_2021    float64
# comp_2021    float64
# dtype: object
# state          object
# part_2017     float64
# ebrw_2017       int64
# math_2017       int64
# total_2017      int64
# dtype: object
# state          object
# part_2018     float64
# ebrw_2018       int64
# math_2018       int64
# total_2018      int64
# dtype: object
# state          object
# part_2019     float64
# ebrw_2019       int64
# math_2019       int64
# total_2019      int64
# dtype: object
# state          object
# part_2020     float64
# ebrw_2020       int64
# math_2020       int64
# total_2020      int64
# dtype: object
# state          object
# ...

# %% [markdown]
# #### Question 9: Merge dataframes that can be merged.

# %%
# Merging act scores into a single file

act_scores = pd.merge(
    pd.merge(
        pd.merge(
            pd.merge(act_2017,act_2018,on='state', how='left'),
            act_2019,on='state', how='left'),
        act_2020,on='state', how='left'),
    act_2021,on='state',how='left')

act_scores.drop(columns=[
    'part_2017',
    'part_2018',
    'part_2019',
    'part_2020',
    'part_2021'], inplace=True)

act_scores
# Out:
#                    state  comp_2017  comp_2018  comp_2019  comp_2020  \
# 0               National       21.0        NaN       20.7       20.7
# 1                Alabama       19.2       19.1       18.9       18.8
# 2                 Alaska       19.8       20.8       20.1       20.1
# 3                Arizona       19.7       19.2       19.0       19.1
# 4               Arkansas       19.4       19.4       19.3       19.0
# 5             California       22.8       22.7       22.6       23.3
# 6               Colorado       20.8       23.9       23.8       23.7
# 7            Connecticut       25.2       25.6       25.5       25.9
# 8               Delaware       24.1       23.8       24.1       24.2
# 9   District of Columbia       24.2        NaN       23.5       23.1
# 10               Florida       19.8       19.9       20.1       20.6
# 11               Georgia       21.4       21.4       21.4       21.7
# 12                Hawaii       19.0       18.9       19.0       18.5
# ...

# %%
# Merging act participations into a single file

act_part = pd.merge(
    pd.merge(
        pd.merge(
            pd.merge(act_2017,act_2018, on='state', how='left'),
            act_2019,on='state', how='left'),
        act_2020,on='state', how='left'),
    act_2021,on='state',how='left')

act_part.drop(columns=[
    'comp_2017',
    'comp_2018',
    'comp_2019',
    'comp_2020',
    'comp_2021'], inplace=True)

# %%
# Merging sat scores into a single file

sat_scores = pd.merge(
    pd.merge(
        pd.merge(
            pd.merge(sat_2017,sat_2018,on='state', how='left'),
            sat_2019,on='state', how='left'),
        sat_2020,on='state', how='left'),
    sat_2021,on='state',how='left')

sat_scores.drop(columns=[
    'part_2017','ebrw_2017','math_2017',
    'part_2018','ebrw_2018','math_2018',
    'part_2019','ebrw_2019','math_2019',
    'part_2020','ebrw_2020','math_2020',
    'part_2021','ebrw_2021','math_2021',], inplace=True)

# %%
sat_scores.head()
# Out:
#         state  total_2017  total_2018  total_2019  total_2020  total_2021
# 0     Alabama        1165        1166        1143        1127        1159
# 1      Alaska        1080        1106        1097        1098        1119
# 2     Arizona        1116        1149        1134        1139        1181
# 3    Arkansas        1208        1169        1141        1157        1194
# 4  California        1055        1076        1065        1049        1057

# %%
# Merging sat participations into a single file

sat_part = pd.merge(
    pd.merge(
        pd.merge(
            pd.merge(sat_2017,sat_2018, on='state', how='left'),
            sat_2019,on='state', how='left'),
        sat_2020,on='state', how='left'),
    sat_2021,on='state',how='left')

sat_part.drop(columns=[
    'ebrw_2017', 'math_2017','total_2017',
    'ebrw_2018', 'math_2018','total_2018',
    'ebrw_2019', 'math_2019','total_2019',
    'ebrw_2020', 'math_2020','total_2020',
    'ebrw_2021', 'math_2021','total_2021'], inplace=True)

# %%
# Removing the National row for ACT participation and score files

act_part.drop(index=0, inplace=True)
act_scores.drop(index=0, inplace=True)

# Resetting the index of the rows
act_part.reset_index(inplace=True)
act_scores.reset_index(inplace=True)

# %% [markdown]
# #### Question 10: Perform any additional cleaning that you feel is necessary.

# %%
# Export the combined scores and participation for ACT

act_scores.to_csv('../data/act_scores_comp.csv', index=False)
act_part.to_csv('../data/act_part.csv', index=False)

# %% [markdown]
# #### Question 11: Save your cleaned and merged dataframes as csv files.

# %%
# Export the combined scores and participation for SAT

sat_scores.to_csv('../data/sat_scores_comp.csv', index=False)
sat_part.to_csv('../data/sat_part.csv', index=False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# | **Feature**          | **Type**  | **Dataset(s)**                                   | **Description**                                                                             |
# |----------------------|-----------|--------------------------------------------------|---------------------------------------------------------------------------------------------|
# | mean_calc            | function  |                         -                        | Function that calculates the average value (mean)                                           |
# | mean_calc_alt        | function  |                         -                        | Alternate version of the function that calculates the average value(mean)                   |
# | dev_calc             | function  |                         -                        | Function that calculates the standard deviation of a given value                            |
# | perc_conv            | function  |                         -                        | Function that transform a percentage into a decimal number                                  |
# | np                   | variable  |                         -                        | Numpy                                                                                       |
# | pd                   | variable  |                         -                        | Pandas                                                                                      |
# | plt                  | variable  |                         -                        | matplotlib.pyplot                                                                           |
# | sbn                  | variable  |                         -                        | Seaborn                                                                                     |
# | csv_type             | function  |                        All                       | Function that return the type of a particular element                                       |
# | disp_data            | function  |                        All                       | Function that return the .head() of a particular element                                    |
# | miss_val_chk         | function  | All                                              | Function that will display the .info() of a particular element                              |
# | rname_cols           | function  | All                                              | Function that force the columns name to lowercase and replace the spaces with a '-'         |
# | act_scores           | DataFrame | act_2017, act_2018, act_2019, act_2020, act_2021 | DataFrame that includes the scores of ACT exams for all states between 2017 and 2021        |
# |          _comp_2017_ | float     | act_scores                                       | Contains the scores of 2017 ACT exams for all states                                        |
# |          _comp_2018_ | float     | act_scores                                       | Contains the scores of 2018 ACT exams for all states                                        |
# |          _comp_2019_ | float     | act_scores                                       | Contains the scores of 2019 ACT exams for all states                                        |
# |          _comp_2020_ | float     | act_scores                                       | Contains the scores of 2020 ACT exams for all states                                        |
# |          _comp_2021_ | float     | act_scores                                       | Contains the scores of 2021 ACT exams for all states                                        |
# |        _comp_pcovid_ | float     | act_scores                                       | Contains the average scores of 2017-2019 of ACT exams for all states                        |
# |        _comp_acovid_ | float     | act_scores                                       | Contains the average scores of 2020-2021 of ACT exams for all states                        |
# |          _comp_diff_ | float     | act_scores                                       | Contains the score difference (pcovid - acovid) of ACT exams for all states                 |
# | act_part             | DataFrame | act_2017, act_2018, act_2019, act_2020, act_2021 | DataFrame that includes the participation of ACT exams for all states between 2017 and 2021 |
# |          _part_2017_ | float     | act_part                                         | Contains the participation of 2017 ACT exams for all states                                 |
# |          _part_2018_ | float     | act_part                                         | Contains the participation of 2018 ACT exams for all states                                 |
# |          _part_2019_ | float     | act_part                                         | Contains the participation of 2019 ACT exams for all states                                 |
# |          _part_2020_ | float     | act_part                                         | Contains the participation of 2020 ACT exams for all states                                 |
# |          _part_2021_ | float     | act_part                                         | Contains the participation of 2021 ACT exams for all states                                 |
# |        _part_pcovid_ | float     | act_part                                         | Contains the average participation of 2017-2019 of ACT exams for all states                 |
# |        _part_pcovid_ | float     | act_part                                         | Contains the average participation of 2020-2021 of ACT exams for all states                 |
# |          _part_diff_ | float     | act_part                                         | Contains the participation difference (pcovid - acovid) of ACT exams for all states         |
# | sat_scores           | DataFrame | sat_2017, sat_2018, sat_2019, sat_2020, sat_2021 | DataFrame that includes the scores of SAT exams for all states between 2017 and 2021        |
# |         _total_2017_ | float     | sat_scores                                       | Contains the scores of 2017 SAT exams for all states                                        |
# |         _total_2018_ | float     | sat_scores                                       | Contains the scores of 2018 SAT exams for all states                                        |
# |         _total_2019_ | float     | sat_scores                                       | Contains the scores of 2019 SAT exams for all states                                        |
# |         _total_2020_ | float     | sat_scores                                       | Contains the scores of 2020 SAT exams for all states                                        |
# |         _total_2021_ | float     | sat_scores                                       | Contains the scores of 2021 SAT exams for all states                                        |
# |       _total_pcovid_ | float     | sat_scores                                       | Contains the average scores of 2017-2019 of SAT exams for all states                        |
# |       _total_acovid_ | float     | sat_scores                                       | Contains the average scores of 2020-2021 of SAT exams for all states                        |
# |         _total_diff_ | float     | sat_scores                                       | Contains the score difference (pcovid - acovid) of SAT exams for all states                 |
# | sat_part             | DataFrame | sat_2017, sat_2018, sat_2019, sat_2020, sat_2021 | DataFrame that includes the participation of SAT exams for all states between 2017 and 2021 |
# |          _part_2017_ | float     | sat_part                                         | Contains the participation of 2017 SAT exams for all states                                 |
# |          _part_2018_ | float     | sat_part                                         | Contains the participation of 2018 SAT exams for all states                                 |
# |          _part_2019_ | float     | sat_part                                         | Contains the participation of 2019 SAT exams for all states                                 |
# |          _part_2020_ | float     | sat_part                                         | Contains the participation of 2020 SAT exams for all states                                 |
# |          _part_2021_ | float     | sat_part                                         | Contains the participation of 2021 SAT exams for all states                                 |
# |        _part_pcovid_ | float     | sat_part                                         | Contains the average participation of 2017-2019 of SAT exams for all states                 |
# |        _part_acovid_ | float     | sat_part                                         | Contains the average participation of 2020-2021 of SAT exams for all states                 |
# |          _part_diff_ | float     | sat_part                                         | Contains the participation difference (pcovid - acovid) of SAT exams for all states         |
# | act_part_covid       | DataFrame | act_part                                         | Contains the 'state', 'part_pcovid', 'part_acvoid' columns                                  |
# | sat_part_covid       | DataFrame | sat_part                                         | Contains the 'state', 'part_pcovid', 'part_acvoid' columns                                  |
# | part_covid           | DataFrame | act_part_covid, sat_part_covid                   | Combined view of act_part_covid and sat_part_covid                                          |
# |    _part_pcovid_act_ | float     | part_covid                                       | Contains the averaged participation for 2017-2019 ACT exams for all states                  |
# | _part_acovid_act_    | float     | part_covid                                       | Contains the averaged participation for 2020-2021 ACT exams for all states                  |
# | _part_pcovid_sat_    | float     | part_covid                                       | Contains the averaged participation for 2017-2019 SAT exams for all states                  |
# | _part_acovid_sat_    | float     | part_covid                                       | Contains the averaged participation for 2020-2021 SAT exams for all states                  |
# | sat_scores_covid     | DataFrame | sat_scores                                       | Contains the 'state', 'part_pcovid', 'part_acvoid' columns                                  |
# | act_scores_covid     | DataFrame | act_scores                                       | Contains the 'state', 'part_pcovid', 'part_acvoid' columns                                  |
# | scores_covid         | DataFrame | sat_scores, act_scores                           | Combined view of act_scores_covid and sat_scores_covid                                      |
# | _scores_pcovid_act_  | float     | scores_covid                                     | Contains the averaged scores for 2017-2019 ACT exams for all states                         |
# | _scores_acovid_act_  | float     | scores_covid                                     | Contains the averaged scores for 2020-2021 ACT exams for all states                         |
# | _scores_pcovid_sat_  | float     | scores_covid                                     | Contains the averaged scores for 2017-2019 SAT exams for all states                         |
# | _scores_acovid_sat_  | float     | scores_covid                                     | Contains the averaged scores for 2020-2021 SAT exams for all states                         |
# | part_scores_combined | DataFrame | part_covid, scores_covid                         | Combined view of part_covid and scores_covid                                                |
# | part_year_combined   | DataFrame | act_part, sat_part                               | Combined view of act_part and sat_part                                                      |
# |      _part_2017_act_ | float     | part_year_combined                               | Contains 2017 participation for ACT for all states                                          |
# |      _part_2018_act_ | float     | part_year_combined                               | Contains 2018 participation for ACT for all states                                          |
# |      _part_2019_act_ | float     | part_year_combined                               | Contains 2019 participation for ACT for all states                                          |
# |      _part_2020_act_ | float     | part_year_combined                               | Contains 2020 participation for ACT for all states                                          |
# |      _part_2021_act_ | float     | part_year_combined                               | Contains 2021 participation for ACT for all states                                          |
# |    _part_pcovid_act_ | float     | part_year_combined                               | Contains averaged participation for years 2017-2019 for ACT for all states                  |
# |    _part_acovid_act_ | float     | part_year_combined                               | Contains averaged participation for years 2020-2021 for ACT for all states                  |
# |      _part_diff_act_ | float     | part_year_combined                               | Contains the participation difference (pcovid - acovid) of ACT exams for all states         |
# |      _part_2017_sat_ | float     | part_year_combined                               | Contains 2017 participation for SAT for all states                                          |
# |      _part_2018_sat_ | float     | part_year_combined                               | Contains 2018 participation for SAT for all states                                          |
# |      _part_2019_sat_ | float     | part_year_combined                               | Contains 2019 participation for SAT for all states                                          |
# |      _part_2020_sat_ | float     | part_year_combined                               | Contains 2020 participation for SAT for all states                                          |
# |      _part_2021_sat_ | float     | part_year_combined                               | Contains 2021 participation for SAT for all states                                          |
# |    _part_pcovid_sat_ | float     | part_year_combined                               | Contains averaged participation for years 2017-2019 for SAT for all states                  |
# |    _part_acovid_sat_ | float     | part_year_combined                               | Contains averaged participation for years 2020-2021 for SAT for all states                  |
# |      _part_diff_sat_ | float     | part_year_combined                               | Contains the participation difference (pcovid - acovid) of SAT exams for all states         |
# | scores_year_combined | DataFrame | act_scores, sat_scores                           | Combined view of act_scores and sat_scores                                                  |
# |      _comp_2017_act_ | float     | scores_year_combined                             | Contains 2017 scores for ACT for all states                                                 |
# |      _comp_2018_act_ | float     | scores_year_combined                             | Contains 2018 scores for ACT for all states                                                 |
# |      _comp_2019_act_ | float     | scores_year_combined                             | Contains 2019 scores for ACT for all states                                                 |
# |      _comp_2020_act_ | float     | scores_year_combined                             | Contains 2020 scores for ACT for all states                                                 |
# |      _comp_2021_act_ | float     | scores_year_combined                             | Contains 2021 scores for ACT for all states                                                 |
# |    _comp_pcovid_act_ | float     | scores_year_combined                             | Contains averaged scores for years 2017-2019 for ACT for all states                         |
# |    _comp_acovid_act_ | float     | scores_year_combined                             | Contains averaged scores for years 2020-2021 for ACT for all states                         |
# |      _comp_diff_act_ | float     | scores_year_combined                             | Contains the scores difference (pcovid - acovid) of ACT exams for all states                |
# |      _comp_2017_sat_ | float     | scores_year_combined                             | Contains 2017 scores for SAT for all states                                                 |
# |      _comp_2018_sat_ | float     | scores_year_combined                             | Contains 2018 scores for SAT for all states                                                 |
# |      _comp_2019_sat_ | float     | scores_year_combined                             | Contains 2019 scores for SAT for all states                                                 |
# |      _comp_2020_sat_ | float     | scores_year_combined                             | Contains 2020 scores for SAT for all states                                                 |
# |      _comp_2021_sat_ | float     | scores_year_combined                             | Contains 2021 scores for SAT for all states                                                 |
# |    _comp_pcovid_sat_ | float     | scores_year_combined                             | Contains averaged scores for years 2017-2019 for SAT for all states                         |
# |    _comp_acovid_sat_ | float     | scores_year_combined                             | Contains averaged scores for years 2020-2021 for SAT for all states                         |
# |      _comp_diff_sat_ | float     | scores_year_combined                             | Contains the participation scores (pcovid - acovid) of SAT exams for all states             |

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
sat_scores.head()
# Out:
#         state  total_2017  total_2018  total_2019  total_2020  total_2021
# 0     Alabama        1165        1166        1143        1127        1159
# 1      Alaska        1080        1106        1097        1098        1119
# 2     Arizona        1116        1149        1134        1139        1181
# 3    Arkansas        1208        1169        1141        1157        1194
# 4  California        1055        1076        1065        1049        1057

# %%
# Dropping The National row from ACT combined files since I need to calculate it manually

act_part.drop(index=0, inplace=True)
act_scores.drop(index=0, inplace=True)

act_part.reset_index(inplace=True)
act_scores.reset_index(inplace=True)

# %% [markdown]
# Dropping the National Row fro ACT files as I will calculate this using Python. Not removing it means that I will get wrong data into my calculations as it doesn't represent any state.

# %% [markdown]
# #### 2. Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe. No loops

# %%
# Dictionary Comprehension for act_scores

{key:dev_calc(act_scores[key]) for key in act_scores.columns if key !='state'}
# Out:
# {'level_0': 14.719601443879744,
#  'index': 14.719601443879744,
#  'comp_2017': 2.0097819224047067,
#  'comp_2018': nan,
#  'comp_2019': 2.1769103954149127,
#  'comp_2020': 2.3890964029215946,
#  'comp_2021': 2.885409876886069}

# %%
# Dictionary Comprehension for act_part

{key:dev_calc(act_part[key]) for key in act_part.columns if key !='state'}
# Out:
# {'level_0': 14.719601443879744,
#  'index': 14.719601443879744,
#  'part_2017': 0.32405708602331523,
#  'part_2018': nan,
#  'part_2019': 0.34430780735456123,
#  'part_2020': 0.3547435460553116,
#  'part_2021': 0.3618956668212199}

# %%
# Dictionary Comprehension for sat_scores

{key:dev_calc(sat_scores[key]) for key in sat_scores.columns if key !="state"}
# Out:
# {'total_2017': 91.58351056778743,
#  'total_2018': 93.22742384464433,
#  'total_2019': 96.24027185617864,
#  'total_2020': 88.36506796493464,
#  'total_2021': 87.49095191313594}

# %%
# Dictionary comprehension for sat_part

{key:dev_calc(sat_part[key]) for key in sat_part.columns if key !='state'}
# Out:
# {'part_2017': 0.3492907076664507,
#  'part_2018': 0.3694661922353942,
#  'part_2019': 0.3836584048685726,
#  'part_2020': 0.3854271585903205,
#  'part_2021': 0.2870813234512301}

# %% [markdown]
# #### 3: Investigate trends in the data.

# %%
# Loading merged data sets

act_scores = pd.read_csv('../data/act_scores_comp.csv')
act_part = pd.read_csv('../data/act_part.csv')
sat_part = pd.read_csv('../data/sat_part.csv')
sat_scores = pd.read_csv('../data/sat_scores_comp.csv')

# %%
# Return the average score and participation for ACT

print(act_part.mean(numeric_only=True).round(2))
print(act_scores.mean(numeric_only=True).round(3))
# Out:
# index        26.50
# part_2017     0.64
# part_2018     0.61
# part_2019     0.58
# part_2020     0.56
# part_2021     0.44
# dtype: float64
# index        26.500
# comp_2017    21.573
# comp_2018    21.504
# comp_2019    21.519
# comp_2020    21.571
# comp_2021    22.077
# dtype: float64

# %% [markdown]
# We can see that the average participation rate for ACT has been consistently dropping since 2017 with the biggest drop in 2021.
#
# At the same time, average scores saw a consistent decrease between 2017 and 2019 but then increased in 2020 and 2021.

# %%
# Return the median score and participation for ACT

print(act_part.median(numeric_only=True))
print(act_scores.median(numeric_only=True))
# Out:
# index        26.500
# part_2017     0.680
# part_2018     0.660
# part_2019     0.515
# part_2020     0.445
# part_2021     0.270
# dtype: float64
# index        26.50
# comp_2017    21.40
# comp_2018    21.30
# comp_2019    21.15
# comp_2020    20.95
# comp_2021    20.75
# dtype: float64

# %% [markdown]
# For ACT, the median participation is pretty similar to the mean for 2017 to 2020. However, for 2021 it is very far from the mean (0.44 to 0.27).
# This means that for 2021 a lot of states had a lower scores compared to 2017 to 2019 but some states had a very high scores with helped mitigate the mean.

# %%
# Return the average score and participation for SAT

print(sat_part.mean(numeric_only=True).round(2))
print(sat_scores.mean(numeric_only=True).round(2))
# Out:
# part_2017    0.40
# part_2018    0.46
# part_2019    0.49
# part_2020    0.49
# part_2021    0.31
# dtype: float64
# total_2017    1126.10
# total_2018    1120.02
# total_2019    1113.08
# total_2020    1100.35
# total_2021    1123.00
# dtype: float64

# %% [markdown]
# We can see that the average participation rate for SAT has been consistently increasing between 2017 and 2019. It stabilised in 2020 and had a big drop in 2021.
#
# At the same time, average scores were consistently dropping until 2020 and only saw a big increase in 2021.
#
# There seems to be a strong correlation between low participation rate and high scores

# %%
# Return the median score and participation for SAT

print(sat_part.median(numeric_only=True))
print(sat_scores.median(numeric_only=True).round(3))
# Out:
# part_2017    0.38
# part_2018    0.52
# part_2019    0.54
# part_2020    0.51
# part_2021    0.26
# dtype: float64
# total_2017    1107.0
# total_2018    1098.0
# total_2019    1097.0
# total_2020    1095.0
# total_2021    1123.0
# dtype: float64

# %% [markdown]
# Participation median is quite similar to the mean for SAT Participation wich mean that the data should be evenly distributed.
#
# Same observation can be made for the scores where the mean is quite similar to the median

# %% [markdown]
# ###### 1: Summary Statistics.

# %%
# Return statistics on the ACT participation
act_part.describe().round(4)
# Out:
#          index  part_2017  part_2018  part_2019  part_2020  part_2021
# count  52.0000    52.0000    51.0000    52.0000    52.0000    52.0000
# mean   26.5000     0.6415     0.6124     0.5765     0.5590     0.4373
# std    15.1548     0.3280     0.3465     0.3495     0.3602     0.3705
# min     1.0000     0.0800     0.0700     0.0600     0.0500     0.0200
# 25%    13.7500     0.3100     0.2700     0.2375     0.2000     0.0900
# 50%    26.5000     0.6800     0.6600     0.5150     0.4450     0.2700
# 75%    39.2500     1.0000     1.0000     1.0000     1.0000     0.8525
# max    52.0000     1.0000     1.0000     1.0000     1.0000     1.0000

# %% [markdown]
# ACT Participation mean is dropping year on year and standard deviation is getting bigger each year.
#
# 2021 is the year with the single lowest participation state.

# %%
# Return statistics on the ACT scores

act_scores.describe().round(4)
# Out:
#          index  comp_2017  comp_2018  comp_2019  comp_2020  comp_2021
# count  52.0000    52.0000    51.0000    52.0000    52.0000    52.0000
# mean   26.5000    21.5731    21.5039    21.5192    21.5712    22.0769
# std    15.1548     2.0376     2.1203     2.2082     2.4210     2.9246
# min     1.0000    17.8000    17.7000    17.9000    17.9000    17.8000
# 25%    13.7500    19.8000    19.9500    19.8000    19.5750    19.7750
# 50%    26.5000    21.4000    21.3000    21.1500    20.9500    20.7500
# 75%    39.2500    23.6250    23.7500    23.8500    23.7250    25.1250
# max    52.0000    25.5000    25.6000    25.5000    26.0000    27.6000

# %% [markdown]
# ACT Scores standard deviation seems to increase year on year. Meaning that the scores are getting more spread out as the years goes by.
#
# The quartile repartition seems to be pretty even  except for 2021 where scores between 50 and 75 are getting higher.
#
# 2021 was also the year with the highest score

# %%
# Return statistics on the SAT participation

sat_part.describe().round(4)
# Out:
#        part_2017  part_2018  part_2019  part_2020  part_2021
# count    51.0000    51.0000    51.0000    51.0000    51.0000
# mean      0.3980     0.4575     0.4906     0.4871     0.3100
# std       0.3528     0.3731     0.3875     0.3893     0.2899
# min       0.0200     0.0200     0.0200     0.0200     0.0100
# 25%       0.0400     0.0450     0.0550     0.0450     0.0250
# 50%       0.3800     0.5200     0.5400     0.5100     0.2600
# 75%       0.6600     0.7750     0.8200     0.8500     0.4800
# max       1.0000     1.0000     1.0000     1.0000     0.9600

# %% [markdown]
# SAT Participation deviation in 2021 is lower than the previous year, meaning that the participation rate for that year is more evenly situated.
#
# 2021 is also the first year where no state has achieved 100% participation.

# %%
# Return statistics on the SAT scores

sat_scores.describe().round(4)
# Out:
#        total_2017  total_2018  total_2019  total_2020  total_2021
# count     51.0000     51.0000     51.0000     51.0000     51.0000
# mean    1126.0980   1120.0196   1113.0784   1100.3529   1123.0000
# std       92.4948     94.1551     97.1979     89.2443     88.3615
# min      950.0000    977.0000    943.0000    936.0000    984.0000
# 25%     1055.5000   1057.5000   1038.0000   1027.5000   1052.5000
# 50%     1107.0000   1098.0000   1097.0000   1095.0000   1123.0000
# 75%     1212.0000   1204.0000   1210.0000   1185.5000   1208.5000
# max     1295.0000   1298.0000   1284.0000   1257.0000   1263.0000

# %% [markdown]
# SAT scores deviation for 2019 is higher than the other years, meaning that scores were more spread out on that particular year

# %%
# Printing the top 5 rows of state participation sorted by 2021 year

sat_part.sort_values(by='part_2021',ascending=False).head(5)
# Out:
#                    state  part_2017  part_2018  part_2019  part_2020  \
# 7               Delaware       1.00       1.00       1.00       1.00
# 8   District of Columbia       1.00       0.92       0.94       1.00
# 12                 Idaho       0.93       1.00       1.00       1.00
# 9                Florida       0.83       0.56       1.00       1.00
# 13              Illinois       0.09       0.99       1.00       0.98
#
#     part_2021
# 7        0.96
# 8        0.90
# 12       0.90
# 9        0.81
# 13       0.80

# %% [markdown]
# Only one state in 2021 had a participation above 90% for SAT

# %%
# Creating three new columns in the act_part file
# part_pcovid will correspond to the participation mean pre covid
# part_acovid will correspond to the participation mean post covid
# part_diff will be the difference between the participation pre covid and post covid

act_part['part_pcovid'] = ((act_part['part_2017'] +
                            act_part['part_2018'] + 
                            act_part['part_2019']) /3)

act_part['part_acovid'] = ((act_part['part_2020'] +
                            act_part['part_2021'])/2)

act_part['part_diff'] = (act_part['part_acovid'] -
                         act_part['part_pcovid'])

# Return the sum of all the negative and positive values in act_part['part_diff']
# We return '1' for every time we browse through act_scores['comp_diff'] where the number is negative and positive

print(sum(1 for x in act_part['part_diff'] if x < 0),
      'states have lower averaged ACT participation during/post Covid period than before')

print(sum(1 for x in act_part['part_diff'] if x > 0),
      'states have higher averaged ACT participaton during/post Covid period than before')

print(sum(1 for x in act_part['part_diff'] if x == 0),
      'states have same averaged ACT participation during/post Covid period and before')

act_part[['state','part_diff']].sort_values(by='part_diff',ascending=True).head(5)   

# A positive number mean an increase post-covid of participation by this much
# A negative number mean a decrease post-covid of participation by this much
# Out:
# 44 states have lower averaged ACT participation during/post Covid period than before
# 2 states have higher averaged ACT participaton during/post Covid period than before
# 5 states have same averaged ACT participation during/post Covid period and before
#              state  part_diff
# 13        Illinois  -0.320000
# 5         Colorado  -0.318333
# 41  South Carolina  -0.296667
# 49   West Virginia  -0.270000
# 32      New Mexico  -0.258333

# %% [markdown]
# More than 86% of states saw a decrease in ACT participation post covid
#
# Only 4% have seen an increase in ACT particpation post Covid
#
# 10% have not seen an increase of a decrease

# %%
# Creating three new columns in the act_scores file
# scores_pcovid will correspond to the participation mean pre covid
# scores_acovid will correspond to the participation mean post covid
# scores_diff will be the difference between the participation pre covid and post covid

act_scores['comp_pcovid'] = ((act_scores['comp_2017'] +
                                act_scores['comp_2018'] +
                                act_scores['comp_2019']) /3)

act_scores['comp_acovid'] = ((act_scores['comp_2020'] +
                                act_scores['comp_2021'])/2)

act_scores['comp_diff'] = (act_scores['comp_acovid'] -
                                act_scores['comp_pcovid']) 

# Return the sum of all the negative and positive values in act_scores['comp_diff']
# We return '1' for every time we browse through act_scores['comp_diff'] where the number is negative and positive

print(sum(1 for x in act_scores['comp_diff'] if x < 0),
      'states have lower averaged ACT scores during/post Covid period than before')

print(sum(1 for x in act_scores['comp_diff'] if x > 0),
      'states have higher averaged ACT scores during/post Covid period than before')

print(sum(1 for x in act_scores['comp_diff'] if x == 0),
      'states have same averaged ACT scores during/post Covid period and before')

act_scores[['state','comp_diff']].sort_values(by='comp_diff',ascending=True).head(5)

# A positive number mean an increase post-covid of participation by this much
# A negative number mean a decrease post-covid of participation by this much
# Out:
# 19 states have lower averaged ACT scores during/post Covid period than before
# 31 states have higher averaged ACT scores during/post Covid period than before
# 1 states have same averaged ACT scores during/post Covid period and before
#         state  comp_diff
# 16     Kansas  -1.350000
# 36       Ohio  -1.016667
# 17   Kentucky  -0.650000
# 18  Louisiana  -0.616667
# 11     Hawaii  -0.616667

# %% [markdown]
# Less than 40% of the states saw an increase in ACT scores post Covid whereas 60% saw a decrease

# %%
# Creating three new columns in the sat_part file
# part_pcovid will correspond to the participation mean pre covid
# part_acovid will correspond to the participation mean post covid
# part_diff will be the difference between the participation pre covid and post covid

sat_part['part_pcovid'] = ((sat_part['part_2017'] +
                            sat_part['part_2018'] +
                            sat_part['part_2019']) /3)

sat_part['part_acovid'] = ((sat_part['part_2020'] +
                            sat_part['part_2021'])/2)

sat_part['part_diff'] = (sat_part['part_acovid'] -
                         sat_part['part_pcovid'])

# Return the sum of all the negative values in act_part['part_diff']
# We return '1' for every time we browse through act_part['part_diff'] where the number is negative

print(sum(1 for x in sat_part['part_diff'] if x < 0.000000),
      'states have lower averaged SAT participation during/post Covid period than before')

print(sum(1 for x in sat_part['part_diff'] if x > 0.000000),
      'states have higher averaged SAT participation during/post Covid period than before')

print(sum(1 for x in sat_part['part_diff'] if x == 0.000000),
      'states have same averaged SAT participation during/post Covid period and before')

sat_part[['state','part_diff']].sort_values(by='part_diff',ascending=True).head(5) 

# A positive number mean an increase post-covid of participation by this much
# A negative number mean a decrease post-covid of participation by this much
# Out:
# 42 states have lower averaged SAT participation during/post Covid period than before
# 9 states have higher averaged SAT participation during/post Covid period than before
# 0 states have same averaged SAT participation during/post Covid period and before
#             state  part_diff
# 19          Maine  -0.341667
# 21  Massachusetts  -0.220000
# 47     Washington  -0.196667
# 11         Hawaii  -0.165000
# 22       Michigan  -0.160000

# %% [markdown]
# 82% of states saw a decrease in SAT participation post Covid
#
# 17% saw an increase

# %%
# Creating three new columns in the sat_scores file
# scores_pcovid will correspond to the participation mean pre covid
# scores_acovid will correspond to the participation mean post covid
# scores_diff will be the difference between the participation pre covid and post covid

sat_scores['total_pcovid'] = ((sat_scores['total_2017'] +
                                sat_scores['total_2018'] +
                                sat_scores['total_2019']) /3)

sat_scores['total_acovid'] = ((sat_scores['total_2020'] +
                               sat_scores['total_2021'])/2)

sat_scores['total_diff'] = (sat_scores['total_acovid'] -
                            sat_scores['total_pcovid']) 

# Return the sum of all the negative and positive values in act_scores['comp_diff']
# We return '1' for every time we browse through act_scores['comp_diff'] where the number is negative and positive

print(sum(1 for x in sat_scores['total_diff'] if x < 0),
      'states have lower averaged SAT scores during/post Covid period than before')

print(sum(1 for x in sat_scores['total_diff'] if x > 0),
      'states have higher averaged SAT scores during/post Covid period than before')

print(sum(1 for x in sat_scores['total_diff'] if x == 0),
      'states have same averaged SAT scores during/post Covid period and before')

# Create a view to count positives negatives diff
print(sat_scores['total_diff'].value_counts(bins= [-100,-0.1,0.1,50]))

sat_scores[['state','total_diff']].sort_values(by='total_diff',ascending=True).head(5)

# A positive number mean an increase post-covid of participation by this much
# A negative number mean a decrease post-covid of participation by this much
# Out:
# 31 states have lower averaged SAT scores during/post Covid period than before
# 20 states have higher averaged SAT scores during/post Covid period than before
# 0 states have same averaged SAT scores during/post Covid period and before
# (-100.001, -0.1]    31
# (0.1, 50.0]         18
# (-0.1, 0.1]          0
# Name: total_diff, dtype: int64
#          state  total_diff
# 31  New Mexico  -75.833333
# 49   Wisconsin  -60.333333
# 35        Ohio  -56.000000
# 9      Florida  -45.833333
# 13    Illinois  -42.000000

# %% [markdown]
# 60% of the states have seen a lower SAT scores post Covid
#
# 40% saw an increase

# %%
# Display Quartiles and then do a count below the values

#Interquartile range ??

print(sat_scores['total_diff'].quantile([.25,.50,.75]))

print(sum(1 for x in sat_scores['total_diff'] if x <= (-24.666667)))

print(sum(1 for x in sat_scores['total_diff'] if x > (-24.666667) and x <= (-15)))

print(sum(1 for x in sat_scores['total_diff'] if x > (-15) and x <= 11))
# Out:
# 0.25   -24.666667
# 0.50   -15.000000
# 0.75    10.500000
# Name: total_diff, dtype: float64
# 13
# 13
# 12

# %%
# Create a view to count positives negatives diff

print(act_scores['comp_diff'].value_counts(bins =[-100,-0.0000001,0.0000001,100]))
print(act_part['part_diff'].value_counts(bins=[-1,-0.00001,0.00001,1]))

print(sat_scores['total_diff'].value_counts(bins= [-100,-0.1,0.1,50]))
print(sat_part['part_diff'].value_counts(bins= [-1,-0.01,0.00001,1]))
# Out:
# (1e-07, 100.0]        31
# (-100.001, -1e-07]    19
# (-1e-07, 1e-07]        1
# Name: comp_diff, dtype: int64
# (-1.001, -1e-05]    44
# (-1e-05, 1e-05]      5
# (1e-05, 1.0]         2
# Name: part_diff, dtype: int64
# (-100.001, -0.1]    31
# (0.1, 50.0]         18
# (-0.1, 0.1]          0
# Name: total_diff, dtype: int64
# (-1.001, -0.01]    29
# (-0.01, 1e-05]     13
# (1e-05, 1.0]        9
# Name: part_diff, dtype: int64

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Creating a dataframe including the act and sat part scores pre-covid

act_part_covid = act_part[['state',
                           'part_pcovid',
                           'part_acovid']]

sat_part_covid = sat_part[['state',
                           'part_pcovid',
                           'part_acovid']]

part_covid = pd.merge(act_part_covid,sat_part_covid,on='state', how='left')


# RENAME THE NEW COLUMNS 
part_covid.columns = ['state',
                      'part_pcovid_act',
                      'part_acovid_act',
                      'part_pcovid_sat',
                      'part_acovid_sat']

act_scores_covid = act_scores[['state',
                              'comp_pcovid',
                              'comp_acovid']]

sat_scores_covid = sat_scores[['state',
                               'total_pcovid',
                               'total_acovid']]

scores_covid = pd.merge(act_scores_covid, sat_scores_covid, on='state', how='left')

# RENAME THE NEW COLUMNS
scores_covid.columns = ['state',
                       'scores_pcovid_act',
                       'scores_acovid_act',
                       'scores_pcovid_sat',
                       'scores_acovid_sat']

part_scores_combined = pd.merge(part_covid, scores_covid, on='state', how='left')

part_scores_combined.head()
# Out:
#         state  part_pcovid_act  part_acovid_act  part_pcovid_sat  \
# 0     Alabama         1.000000            1.000         0.060000
# 1      Alaska         0.453333            0.245         0.406667
# 2     Arizona         0.670000            0.530         0.300000
# 3    Arkansas         1.000000            0.995         0.046667
# 4  California         0.270000            0.120         0.586667
#
#    part_acovid_sat  scores_pcovid_act  scores_acovid_act  scores_pcovid_sat  \
# 0            0.050          19.066667              18.75        1158.000000
# 1            0.300          20.233333              20.35        1094.333333
# 2            0.200          19.300000              19.45        1133.000000
# 3            0.030          19.366667              19.00        1172.666667
# 4            0.455          22.700000              24.70        1065.333333
#
#    scores_acovid_sat
# 0             1143.0
# 1             1108.5
# 2             1160.0
# 3             1175.5
# ...

# %%
# Creating a new dataframe for ACT_SAT Participations and scores combined to help with the plots

part_year_combined = pd.merge(act_part,sat_part,on='state', how='left')
scores_year_combined = pd.merge(act_scores,sat_scores,on='state', how='left')

#RENAMING COLUMNS

part_year_combined.columns = ['index','state',
                             'part_2017_act',
                             'part_2018_act',
                             'part_2019_act',
                             'part_2020_act',
                             'part_2021_act',
                             'part_pcovid_act',
                             'part_acovid_act',
                             'part_diff_act',
                             'part_2017_sat',
                             'part_2018_sat',
                             'part_2019_sat',
                             'part_2020_sat',
                             'part_2021_sat',
                             'part_pcovid_sat',
                             'part_acovid_sat',
                             'part_diff_sat']

scores_year_combined.columns = ['index','state',
                             'comp_2017_act',
                             'comp_2018_act',
                             'comp_2019_act',
                             'comp_2020_act',
                             'comp_2021_act',
                             'comp_pcovid_act',
                             'comp_acovid_act',
                             'comp_diff_act',
                             'comp_2017_sat',
                             'comp_2018_sat',
                             'comp_2019_sat',
                             'comp_2020_sat',
                             'comp_2021_sat',
                             'comp_pcovid_sat',
                             'comp_acovid_sat',
                             'comp_diff_sat']

# %%
# Dropping columns that will not be used

part_year_combined.drop(['part_pcovid_act',
                         'part_acovid_act',
                         'part_pcovid_sat',
                         'part_acovid_sat',
                         'part_diff_act',
                         'part_diff_sat'], axis=1, inplace=True)

scores_year_combined.drop(['comp_pcovid_act',
                         'comp_acovid_act',
                         'comp_pcovid_sat',
                         'comp_acovid_sat',
                         'comp_diff_act',
                         'comp_diff_sat'], axis=1, inplace=True)

# %%
# Plotting the difference of scores mean pre and post covid

sat_scores[['state','total_2017','total_2018','total_acovid','total_pcovid']].plot(x='state', figsize=(50,12), kind='bar')
# Out:
# <AxesSubplot:xlabel='state'>

# %%
# Plotting participation pre and post covid by state for sat

sat_part[['state','part_acovid','part_pcovid']].plot(x='state', figsize=(50,12), kind='bar')
plt.savefig('../data/figs/sat_pcovid_acovid_part.png')

# %%
# Plotting participation pre and post covid by state for ACT

act_part[['state','part_acovid','part_pcovid']].plot(x='state', figsize=(50,12), kind='bar')
plt.savefig('../data/figs/act_pcovid_acovid_part.png')

# %%
# Plotting scores pre and post covid by state for ACT

act_scores[['state','comp_acovid','comp_pcovid']].plot(x='state',figsize=(50,12),kind='bar')
plt.savefig('../data/figs/act_acovid_pcovid_scores.png')

# %%
# Displaying states where the participation after covid whas above 70%

part_covid[['state','part_acovid_act','part_acovid_sat']].loc[
    part_covid['part_acovid_sat'] > 0.7, :].sort_values(
    by='part_acovid_sat')
# Out:
#                    state  part_acovid_act  part_acovid_sat
# 49         West Virginia            0.340            0.715
# 5               Colorado            0.205            0.780
# 30         New Hampshire            0.080            0.820
# 23              Michigan            0.130            0.840
# 40          Rhode Island            0.075            0.840
# 6            Connecticut            0.140            0.845
# 13              Illinois            0.250            0.890
# 9                Florida            0.400            0.905
# 8   District of Columbia            0.260            0.950
# 12                 Idaho            0.220            0.950
# 7               Delaware            0.080            0.980

# %%
# Displaying participation pre covid for ACT and SAT by State

part_covid[['state',
            'part_pcovid_act',
            'part_pcovid_sat']].sort_values(by='part_pcovid_act').plot(x='state',figsize=(12,20),kind='barh')
#plt.savefig('../data/figs/part_sat_act_comparison.png')
# Out:
# <AxesSubplot:ylabel='state'>

# %%
# Participation after covid for ACT and SAT by state where SAT is above 70%
# When passing the condition, use the .loc

part_covid[['state','part_acovid_act','part_acovid_sat']].loc[
    part_covid['part_acovid_sat'] > 0.7, :].sort_values(
    by='part_acovid_sat').plot(
    x='state',figsize=(12,5),kind='barh')
# Out:
# <AxesSubplot:ylabel='state'>

# %%
# Participation pre covid for ACT and post covid for SAT by State 

part_covid[['state',
            'part_pcovid_act',
            'part_acovid_sat']].sort_values(
    by='part_pcovid_act').plot(
    x='state', figsize=(12,20),kind='barh')
# Out:
# <AxesSubplot:ylabel='state'>

# %%
# Participation post covid for ACT and pre covid for SAT by State 

part_covid[['state',
            'part_pcovid_sat',
            'part_acovid_act']].sort_values(
    by='part_pcovid_sat').plot(
    x='state', figsize=(12,20),kind='barh')
# Out:
# <AxesSubplot:ylabel='state'>

# %%
# Scatter plot of ACT participation pre and post Covid

part_scores_combined.plot(x='part_acovid_sat',y='scores_acovid_sat', figsize=(15,5),kind='scatter')
# Out:
# <AxesSubplot:xlabel='part_acovid_sat', ylabel='scores_acovid_sat'>

# %%
# Scatter plot of SAT participation and scores pre Covid

part_scores_combined.plot(x='part_pcovid_sat', y='scores_pcovid_sat', figsize=(15,5), kind='scatter')
# Out:
# <AxesSubplot:xlabel='part_pcovid_sat', ylabel='scores_pcovid_sat'>

# %%
# Scatter plot of participation pre and post Covid for ACT

part_scores_combined.plot(x='part_pcovid_act', y='part_acovid_act', figsize=(15,5), kind='scatter')
# Out:
# <AxesSubplot:xlabel='part_pcovid_act', ylabel='part_acovid_act'>

# %%
# Creating a multi histogram of participation and scores pre and post Covid

part_scores_combined.hist(figsize=(16,8),sharey=True, bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'part_pcovid_act'}>,
#         <AxesSubplot:title={'center':'part_acovid_act'}>,
#         <AxesSubplot:title={'center':'part_pcovid_sat'}>],
#        [<AxesSubplot:title={'center':'part_acovid_sat'}>,
#         <AxesSubplot:title={'center':'scores_pcovid_act'}>,
#         <AxesSubplot:title={'center':'scores_acovid_act'}>],
#        [<AxesSubplot:title={'center':'scores_pcovid_sat'}>,
#         <AxesSubplot:title={'center':'scores_acovid_sat'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Be thorough in your verbal description of these distributions.
# Be sure to back up these summaries with statistics.
# We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
# HISTOGRAM THAT SHOWS THE REPARTITION OF SAT PARTICIPATION AFTER COVID

part_scores_combined['part_acovid_sat'].plot(kind='hist',bins=10);
plt.xlabel('Participation');
plt.ylabel('Scores');

# %%
# HISTOGRAM THAT SHOWS THE REPARTITION OF ACT PARTICIPATION AFTER COVID

part_scores_combined['part_acovid_act'].plot(kind='hist',bins=10);
plt.xlabel('Participation');
plt.ylabel('Scores');

# %% [markdown]
# There is a high negative correlation between SAT participation and SAT scores.
# The higher the attendance, the lesser the score

# %%
# Participation for West Virginia for ACT before Covid and SAT post Covid

part_covid[['state','part_pcovid_act','part_pcovid_sat']].loc[
    part_covid['state'] == ('West Virginia'), :].plot(
    x='state',figsize=(5,5),kind='barh')
# Out:
# <AxesSubplot:ylabel='state'>

# %%
# CREATING A BOX PLOT

part_covid.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# Creating a heatmap based on the correlation matrix of SAT Scores

sbn.heatmap(sat_scores.corr(),annot = True, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Based on the heatmap above, it seems that the SAT scores have a high positive correlation between each other.

# %% [markdown]
# ## Visualizations used in presentation

# %%
# SAT and ACT participation comparison throughout the years (2017-2021)

# Creating the first line for ACT participation
part_year_combined[['part_2017_act', 'part_2018_act', 'part_2019_act',
       'part_2020_act', 'part_2021_act']].mean().plot(
    kind = 'line', alpha = 1, label = "ACT Part")

# Creating second line for SAT participation
part_year_combined[['part_2017_sat', 'part_2018_sat',
       'part_2019_sat', 'part_2020_sat', 'part_2021_sat']].mean().plot(
    kind = 'line', alpha = 1, label='SAT Part', figsize =(10,5))

plt.title(label='ACT and SAT Participation from 2017 to 2021')
plt.legend(loc=1)
plt.xlabel('Years')
plt.ylabel('Particpation\n(%)')
plt.xticks(ticks =[0,1,2,3,4],labels=['2017','2018','2019','2020','2021'])

plt.savefig('../data/figs/sat_act_part_comparison.png')

# %% [markdown]
# ACT participation has been consistently dropping between 2017 to 2020. However there has been a significant drop after 2020.
#
# SAT Participation has seen a constant increase between 2017 and 2019. It stabilised during 2020 and saw a significant drop similar to ACT particiation in 2021.
#
# These significant drops could be linked to:
# * Some states choosing to become test optional
# * The Covid disruption of exam center and student preparation

# %%
# ACT Scores progression throughout the years

scores_year_combined[['comp_2017_act', 'comp_2018_act', 'comp_2019_act',
       'comp_2020_act', 'comp_2021_act']].mean().plot(kind = 'line', alpha = 1, label = "ACT Scores", figsize=(10,5))

plt.legend()
plt.title(label='ACT Scores from 2017 to 2021')
plt.legend(loc=2)
plt.xlabel('Years')
plt.ylabel('Scores\n(1 to 36)')
plt.xticks(ticks =[0,1,2,3,4],labels=['2017','2018','2019','2020','2021'])

plt.savefig('../data/figs/act_scores_comparison.png')

# %% [markdown]
# We know that ACT participation hass been slowly decreasing throughout the years with a significantly higher drop in 2021.
# ACT scores follow an opposite trend. They have been slowly increasing between 2018 and 2020 and saw a massive increase in 2021.
#
# We can conclude that ACT participation has a strong negative correlation with ACT scores.

# %%
# SAT Scores progression throughout the years 

scores_year_combined[['comp_2017_sat', 'comp_2018_sat',
       'comp_2019_sat', 'comp_2020_sat', 'comp_2021_sat']].mean().plot(
    kind = 'line', alpha = 1, label='SAT Scores', figsize=(10,5))

plt.legend()
plt.title(label='ACT Scores from 2017 to 2021')
plt.legend(loc=3)
plt.xlabel('Years')
plt.ylabel('Scores\n(400 to 1600)')
plt.xticks(ticks =[0,1,2,3,4],labels=['2017','2018','2019','2020','2021'])

plt.savefig('../data/figs/sat_scores_comparison.png')

# %% [markdown]
# We know that SAT participation has been slowly increasing throughout the years until 2021 where it significantly dropped.
# SAT scores follow an opposite trend. They have been consistently decreasing while the participation was increasing. Only 2021 where participation dropped has seen in increase in scores.
#
# We can conclude that SAT participation also has a strong negative correlation with SAT scores.

# %%
# Displaying States with highest increase in participation post-covid for SAT 

sat_part[['state','part_diff']].loc[
    sat_part['part_diff'] > (0.1), :].sort_values(
    by='part_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 1,)

plt.title(label='SAT Participation Increase above 10%')
plt.legend(loc=4)
plt.xlabel('Participation Increase\n(%)')
plt.ylabel('States')

plt.savefig('../data/figs/sat_part_increase.png')

# %% [markdown]
# We notice that 3 states have had an increase in participation Post-Covid superior to 10%
# * West Virginia
# * Illinois
# * Florida

# %%
# Displaying States with highest decrease in participation post-covid for ACT 

act_part[['state','part_diff']].loc[
    act_part['part_diff'] < (-0.20), :].sort_values(
    by='part_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 0.7, color='orange')

plt.title(label='ACT Participation Decrease Superior 10%')
plt.legend(loc=2)
plt.xlabel('Participation Decrease\n(%)')
plt.ylabel('States')

plt.savefig('../data/figs/act_part_decrease.png')

# %% [markdown]
# We notice that 6 states have had decrease in participation Post-Covid around 25%
# * Illinois
# * Colorado
# * South Carolina
# * West Virginia
# * New Mexico
# * Florida
#
# Using the previous graph we can see that among the 6 states with the biggest drop in participation in ACT,3 of them are  the 3 states with the highest participation in SAT Post-Covid.
# This means that these were relying more heavily on ACT pre-covid and either chose or were forced to make the change to SAT during Covid period.

# %%
# Displaying States with highest decrease in participation post-covid for SAT 

sat_part[['state','part_diff']].loc[
    sat_part['part_diff'] < (-0.15), :].sort_values(
    by='part_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 1,)

plt.title(label='SAT Participation Decrease Superior 15%')
plt.legend(loc=2)
plt.xlabel('Participation Decrease\n(%)')
plt.ylabel('States')

plt.savefig('../data/figs/sat_part_decrease.png')

# %% [markdown]
# We notice that 3 states have had an decrease in participation Post-Covid superior to 15%
# * Maine
# * Massachusetts
# * Washington

# %%
# Displaying States with highest increase in participation post-covid for ACT 

act_part[['state','part_diff']].loc[
    act_part['part_diff'] > (0), :].sort_values(
    by='part_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 0.7, color='orange')

plt.title(label='ACT Participation Increase Superior 0%')
plt.legend(loc=2)
plt.xlabel('Participation Increase\n(%)')
plt.ylabel('States')

plt.savefig('../data/figs/act_part_increase.png')

# %% [markdown]
# Only 2 states, Kansas and Ohio had an increase in participation of ACT suring the Covid period.

# %%
# Displaying States with highest decrease in scores post-covid for SAT 

sat_scores[['state','total_diff']].loc[
    sat_scores['total_diff'] < (-35), :].sort_values(
    by='total_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 1,)

plt.title(label='SAT Score Decrease Superior 35 points')
plt.legend(loc=2)
plt.xlabel('Score Decrease\n(value)')
plt.ylabel('States')

plt.savefig('../data/figs/sat_score_decrease.png')

# %% [markdown]
# There are 9 states with a decrease of more than 35 points in SAT score.
#
# Among these 9 states we can find our 3 states that had the highest increase in participation:
# * West Virginia
# * Illinois
# * Florida
#
# None of the state with the highest decrease in participation have seen a decrease in scores.
#
# This reinforce the idea that the participation and score have a strong negative correlation.

# %%
# Displaying States with highest increase in scores post-covid for ACT 

act_scores[['state','comp_diff']].loc[
    act_scores['comp_diff'] > (1), :].sort_values(
    by='comp_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 0.7, color='orange')

plt.title(label='ACT Score Increase Superior 1 point(s)')
plt.legend(loc=4)
plt.xlabel('Score Increase\n(value)')
plt.ylabel('States')

plt.savefig('../data/figs/act_score_increase.png')

# %% [markdown]
# There are 10 states with an increase of more than 1 point in ACT scores.
#
# Among these 10 states we can only find Illinois from the states that had the highest decrease in participation:
# * Illinois
#
# None of the state with the highest increase in participation have seen an increase in scores.
#
# This reinforce the idea that the participation and score have a strong negative correlation.

# %%
# Displaying States with highest increase in scores post-covid for SAT 

sat_scores[['state','total_diff']].loc[
    sat_scores['total_diff'] > (30), :].sort_values(
    by='total_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 1,)

plt.title(label='SAT Score Increase Superior 30 point(s)')
plt.legend(loc=4)
plt.xlabel('Score Increase\n(value)')
plt.ylabel('States')

plt.savefig('../data/figs/sat_score_increase.png')

# %% [markdown]
# There are 5 states with an increase of more than 30 point in SAT scores.
#
# Among these 5 states we can only find 3 from the states that had the highest decrease in participation:
# * Maine
# * Massachusetts
# * Hawaii
#
#
# None of the state with the highest increase in participation have seen an increase in scores.
#
# This reinforce the idea that the participation and score have a strong negative correlation.

# %%
# Displaying States with highest decrease in scores post-covid for ACT 

act_scores[['state','comp_diff']].loc[
    act_scores['comp_diff'] < (-0.5), :].sort_values(
    by='comp_diff').plot(
    x='state',kind = 'barh',figsize=(10,5), alpha = 0.7, color='orange')

plt.title(label='ACT Score Decrease Superior 0.5 point(s)')
plt.legend(loc=2)
plt.xlabel('Score Decrease\n(value)')
plt.ylabel('States')

plt.savefig('../data/figs/act_score_decrease.png')

# %% [markdown]
# There are 8 states with a decrease of more than 0.5 points in ACT score.
#
# Among these 8 states, the two only states that had an increase in participation are the two highest state in terme of score decrease:
# * Kansas
# * Ohio
#
# None of the state with the highest decrease in participation have seen a decrease in scores.
#
# This reinforce the idea that the participation and score have a strong negative correlation.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# Overall, we can see that Covid has had a big impact on the ACT and SAT Participation.
#
# - SAT Participation was steadily increasing before 2020 and has been dropping since.
# - For ACT, participation was slowing decreasing (probably due to a loss of interest at the profit of SAT) pre-covid.
#     However, for 2021, participation has been dropping heavily.
#
# This could be due mainly to two factors
# * Examination center and schools were disrupted by Covid and as such did not allow students to prepare and take on the exams
# * Some schools and states have decided to go test optional or remove the tests results from their applications.
#
# Recommendation:
# - Analyse post Covid participations to see if ACT can gain back some momentum
# - Check if some schools or states decides to reinstate the tests and the effect on participation.
#
#
# - ACT Participation post Covid has been more impacted than the SAT Participation.
# * Only 2 states (Ohio and Kansas) managed to have a higher ACT participation during/after Covid period while 44 states have a lower participation.
# 44 states have lower averaged ACT participation during/post Covid period than before
# 2 states have higher averaged ACT participaton during/post Covid period than before
# 5 states have same averaged ACT participation during/post Covid period and before
#
# Whereas 9 states had a higher participation SAT participation for 42 with lower participation
# 42 states have lower averaged SAT participation during/post Covid period than before
# 9 states have higher averaged SAT participation during/post Covid period than before
# 0 states have same averaged SAT participation during/post Covid period and before
#
# - It seems that there is also a correlation between the participation rate and the score
#
# 19 states have lower averaged ACT scores during/post Covid period than before
# 31 states have higher averaged ACT scores during/post Covid period than before
# 1 states have same averaged ACT scores during/post Covid period and before
#
# 31 states have lower averaged SAT scores during/post Covid period than before
# 20 states have higher averaged SAT scores during/post Covid period than before
# 0 states have same averaged SAT scores during/post Covid period and before
#
# Among the states with the highest increase in partications for one exam, we can often see that they are the ones with the highest decrease in scorer.
# This is also true for states with the highest decrease in participation. They have the highest increase in scores.
#
# This could mean that only those who needed to take the exams, while those with less necessity for test results opted to skip them.
#
# Finally,
#
# Globally it seems that is a correlation between the decrease in participation of ACT and the increase in SAT.
# The five states with the highest increase in SAT Participation...
# * Colorado
# * New Mexico
# * Florida
# * Illinois
# * West Virginia
#
# ...Are among the highest decrease in participation for ACT exams.
#
# Since ACT participation as been dropping consistently since 2017 and SAT has been increasing, this particular phenomenon could follow a trend of states slowly moving from ACT to SAT
# This could also be due to the SAT exam being more available to take on during Covid time for these specific tests
#
# Recommendation:
# * Analyse the trend in participation in ACT and SAT for every state throughout the years and see if there is a correlation
# * More research on exam taking availability in each state during Covid period.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
